# %% [markdown]
# ### Import required packages and limit GPU usage

# %%
import numpy as np
import math

# %matplotlib inline
import matplotlib.pyplot as plt

import pickle
import argparse
import time
import itertools
from copy import deepcopy
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import networks
import utils
    
# %load_ext autoreload
# %autoreload 2

# %%
use_gpu = True    # set use_gpu to True if system has gpu
gpu_id = 2        # id of gpu to be used
cpu_device = torch.device('cpu')
# fast_device is where computation (training, inference) happens
fast_device = torch.device('cpu')
if use_gpu:
    os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2'    # set visible devices depending on system configuration
    fast_device = torch.device('cuda:' + str(gpu_id))

# %%
def reproducibilitySeed():
    """
    Ensure reproducibility of results; Seeds to 0
    """
    torch_init_seed = 0
    torch.manual_seed(torch_init_seed)
    numpy_init_seed = 0
    np.random.seed(numpy_init_seed)
    if use_gpu:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

reproducibilitySeed()

# %% [markdown]
# ### Load dataset

# %%
import torchvision
import torchvision.transforms as transforms

mnist_image_shape = (28, 28)
random_pad_size = 2
# Training images augmented by randomly shifting images by at max. 2 pixels in any of 4 directions
transform_train = transforms.Compose(
                [
                    transforms.RandomCrop(mnist_image_shape, random_pad_size),
                    transforms.ToTensor(),
                    transforms.Normalize((0.5, 0.5), (0.5, 0.5))
                ]
            )

transform_test = transforms.Compose(
                [
                    transforms.ToTensor(),
                    transforms.Normalize((0.5, 0.5), (0.5, 0.5))
                ]
            )

train_val_dataset = torchvision.datasets.MNIST(root='./MNIST_dataset/', train=True, 
                                            download=True, transform=transform_train)

test_dataset = torchvision.datasets.MNIST(root='./MNIST_dataset/', train=False, 
                                            download=True, transform=transform_test)

num_train = int(1.0 * len(train_val_dataset) * 95 / 100)
num_val = len(train_val_dataset) - num_train
train_dataset, val_dataset = torch.utils.data.random_split(train_val_dataset, [num_train, num_val])

batch_size = 128
train_val_loader = torch.utils.data.DataLoader(train_val_dataset, batch_size=128, shuffle=True, num_workers=2)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=128, shuffle=False, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=2)

# %% [markdown]
# ### Train teacher network

# %%
checkpoints_path = 'checkpoints_teacher/'
if not os.path.exists(checkpoints_path):
    os.mkdir(checkpoints_path)

# %%
num_epochs = 60
print_every = 100    # Interval size for which to print statistics of training

# %%
# Hyperparamters can be tuned by setting required range below
# learning_rates = list(np.logspace(-4, -2, 3))
learning_rates = [1e-2]
learning_rate_decays = [0.95]    # learning rate decays at every epoch
# weight_decays = [0.0] + list(np.logspace(-5, -1, 5))
weight_decays = [1e-5]           # regularization weight
momentums = [0.9]
# dropout_probabilities = [(0.2, 0.5), (0.0, 0.0)]
dropout_probabilities = [(0.0, 0.0)]
hparams_list = []
for hparam_tuple in itertools.product(dropout_probabilities, weight_decays, learning_rate_decays, 
                                        momentums, learning_rates):
    hparam = {}
    hparam['dropout_input'] = hparam_tuple[0][0]
    hparam['dropout_hidden'] = hparam_tuple[0][1]
    hparam['weight_decay'] = hparam_tuple[1]
    hparam['lr_decay'] = hparam_tuple[2]
    hparam['momentum'] = hparam_tuple[3]
    hparam['lr'] = hparam_tuple[4]
    hparams_list.append(hparam)

results = {}
for hparam in hparams_list:
    print('Training with hparams' + utils.hparamToString(hparam))
    reproducibilitySeed()
    teacher_net = networks.TeacherNetwork()
    teacher_net = teacher_net.to(fast_device)
    hparam_tuple = utils.hparamDictToTuple(hparam)
    results[hparam_tuple] = utils.trainTeacherOnHparam(teacher_net, hparam, num_epochs, 
                                                        train_val_loader, None, 
                                                        print_every=print_every, 
                                                        fast_device=fast_device)
    save_path = checkpoints_path + utils.hparamToString(hparam) + '_final.tar'
    torch.save({'results' : results[hparam_tuple], 
                'model_state_dict' : teacher_net.state_dict(), 
                'epoch' : num_epochs}, save_path)
# Out:
# Training with hparamsdropout_hidden=0.0, dropout_input=0.0, lr=0.01, lr_decay=0.95, momentum=0.9, weight_decay=1e-05
# [1,   100/  469] train loss: 0.936 train accuracy: 0.766
# [1,   200/  469] train loss: 0.717 train accuracy: 0.805
# [1,   300/  469] train loss: 0.548 train accuracy: 0.852
# [1,   400/  469] train loss: 0.311 train accuracy: 0.922
# [2,   100/  469] train loss: 0.327 train accuracy: 0.891
# [2,   200/  469] train loss: 0.301 train accuracy: 0.906
# [2,   300/  469] train loss: 0.187 train accuracy: 0.961
# [2,   400/  469] train loss: 0.248 train accuracy: 0.914
# [3,   100/  469] train loss: 0.152 train accuracy: 0.977
# [3,   200/  469] train loss: 0.194 train accuracy: 0.953
# [3,   300/  469] train loss: 0.171 train accuracy: 0.961
# [3,   400/  469] train loss: 0.145 train accuracy: 0.961
# [4,   100/  469] train loss: 0.297 train accuracy: 0.914
# [4,   200/  469] train loss: 0.166 train accuracy: 0.969
# [4,   300/  469] train loss: 0.249 train accuracy: 0.930
# [4,   400/  469] train loss: 0.120 train accuracy: 0.961
# [5,   100/  469] train loss: 0.178 train accuracy: 0.945
# [5,   200/  469] train loss: 0.173 train accuracy: 0.945
# [5,   300/  469] train loss: 0.108 train accuracy: 0.969
# [5,   400/  469] train loss: 0.139 train accuracy: 0.938
# [6,   100/  469] train loss: 0.165 train accuracy: 0.961
# [6,   200/  469] train loss: 0.166 train accuracy: 0.945
# [6,   300/  469] train loss: 0.142 train accuracy: 0.961
# [6,   400/  469] train loss: 0.189 train accuracy: 0.961
# [7,   100/  469] train loss: 0.083 train accuracy: 0.961
# [7,   200/  469] train loss: 0.111 train accuracy: 0.969
# [7,   300/  469] train loss: 0.163 train accuracy: 0.953
# [7,   400/  469] train loss: 0.159 train accuracy: 0.961
# [8,   100/  469] train loss: 0.180 train accuracy: 0.953
# [8,   200/  469] train loss: 0.146 train accuracy: 0.945
# [8,   300/  469] train loss: 0.043 train accuracy: 0.992
# [8,   400/  469] train loss: 0.081 train accuracy: 0.961
# [9,   100/  469] train loss: 0.215 train accuracy: 0.953
# [9,   200/  469] train loss: 0.052 train accuracy: 0.977
# [9,   300/  469] train loss: 0.085 train accuracy: 0.992
# [9,   400/  469] train loss: 0.078 train accuracy: 0.969
# [10,   100/  469] train loss: 0.067 train accuracy: 0.969
# [10,   200/  469] train loss: 0.138 train accuracy: 0.969
# [10,   300/  469] train loss: 0.092 train accuracy: 0.961
# [10,   400/  469] train loss: 0.111 train accuracy: 0.969
# [11,   100/  469] train loss: 0.112 train accuracy: 0.984
# [11,   200/  469] train loss: 0.104 train accuracy: 0.984
# [11,   300/  469] train loss: 0.031 train accuracy: 0.992
# [11,   400/  469] train loss: 0.043 train accuracy: 0.984
# [12,   100/  469] train loss: 0.125 train accuracy: 0.945
# [12,   200/  469] train loss: 0.026 train accuracy: 1.000
# [12,   300/  469] train loss: 0.074 train accuracy: 0.977
# [12,   400/  469] train loss: 0.128 train accuracy: 0.969
# [13,   100/  469] train loss: 0.105 train accuracy: 0.961
# [13,   200/  469] train loss: 0.123 train accuracy: 0.969
# [13,   300/  469] train loss: 0.101 train accuracy: 0.969
# [13,   400/  469] train loss: 0.047 train accuracy: 0.984
# [14,   100/  469] train loss: 0.046 train accuracy: 0.992
# [14,   200/  469] train loss: 0.067 train accuracy: 0.977
# [14,   300/  469] train loss: 0.088 train accuracy: 0.977
# [14,   400/  469] train loss: 0.048 train accuracy: 0.984
# [15,   100/  469] train loss: 0.036 train accuracy: 0.992
# [15,   200/  469] train loss: 0.045 train accuracy: 0.984
# [15,   300/  469] train loss: 0.087 train accuracy: 0.969
# [15,   400/  469] train loss: 0.052 train accuracy: 0.984
# [16,   100/  469] train loss: 0.045 train accuracy: 0.984
# [16,   200/  469] train loss: 0.045 train accuracy: 0.977
# [16,   300/  469] train loss: 0.161 train accuracy: 0.969
# [16,   400/  469] train loss: 0.091 train accuracy: 0.961
# [17,   100/  469] train loss: 0.075 train accuracy: 0.992
# [17,   200/  469] train loss: 0.030 train accuracy: 0.984
# [17,   300/  469] train loss: 0.047 train accuracy: 0.984
# [17,   400/  469] train loss: 0.099 train accuracy: 0.984
# [18,   100/  469] train loss: 0.044 train accuracy: 0.984
# [18,   200/  469] train loss: 0.050 train accuracy: 0.992
# [18,   300/  469] train loss: 0.021 train accuracy: 0.992
# [18,   400/  469] train loss: 0.031 train accuracy: 0.992
# [19,   100/  469] train loss: 0.039 train accuracy: 0.984
# [19,   200/  469] train loss: 0.029 train accuracy: 0.992
# [19,   300/  469] train loss: 0.016 train accuracy: 1.000
# [19,   400/  469] train loss: 0.064 train accuracy: 0.969
# [20,   100/  469] train loss: 0.035 train accuracy: 1.000
# [20,   200/  469] train loss: 0.073 train accuracy: 0.984
# [20,   300/  469] train loss: 0.024 train accuracy: 0.992
# [20,   400/  469] train loss: 0.055 train accuracy: 0.977
# [21,   100/  469] train loss: 0.008 train accuracy: 1.000
# [21,   200/  469] train loss: 0.017 train accuracy: 1.000
# [21,   300/  469] train loss: 0.037 train accuracy: 0.984
# [21,   400/  469] train loss: 0.083 train accuracy: 0.969
# [22,   100/  469] train loss: 0.064 train accuracy: 0.977
# [22,   200/  469] train loss: 0.137 train accuracy: 0.961
# [22,   300/  469] train loss: 0.034 train accuracy: 0.992
# [22,   400/  469] train loss: 0.079 train accuracy: 0.977
# [23,   100/  469] train loss: 0.077 train accuracy: 0.961
# [23,   200/  469] train loss: 0.076 train accuracy: 0.984
# [23,   300/  469] train loss: 0.099 train accuracy: 0.969
# [23,   400/  469] train loss: 0.066 train accuracy: 0.969
# [24,   100/  469] train loss: 0.029 train accuracy: 0.992
# [24,   200/  469] train loss: 0.022 train accuracy: 0.992
# [24,   300/  469] train loss: 0.046 train accuracy: 0.984
# [24,   400/  469] train loss: 0.125 train accuracy: 0.969
# [25,   100/  469] train loss: 0.032 train accuracy: 0.992
# [25,   200/  469] train loss: 0.066 train accuracy: 0.969
# [25,   300/  469] train loss: 0.032 train accuracy: 0.984
# [25,   400/  469] train loss: 0.104 train accuracy: 0.984
# [26,   100/  469] train loss: 0.028 train accuracy: 0.992
# [26,   200/  469] train loss: 0.028 train accuracy: 0.992
# [26,   300/  469] train loss: 0.098 train accuracy: 0.961
# [26,   400/  469] train loss: 0.030 train accuracy: 0.984
# [27,   100/  469] train loss: 0.078 train accuracy: 0.961
# [27,   200/  469] train loss: 0.078 train accuracy: 0.977
# [27,   300/  469] train loss: 0.026 train accuracy: 0.992
# [27,   400/  469] train loss: 0.056 train accuracy: 0.977
# [28,   100/  469] train loss: 0.042 train accuracy: 0.977
# [28,   200/  469] train loss: 0.012 train accuracy: 1.000
# [28,   300/  469] train loss: 0.042 train accuracy: 0.984
# [28,   400/  469] train loss: 0.058 train accuracy: 0.977
# [29,   100/  469] train loss: 0.018 train accuracy: 0.992
# [29,   200/  469] train loss: 0.023 train accuracy: 0.992
# [29,   300/  469] train loss: 0.073 train accuracy: 0.969
# [29,   400/  469] train loss: 0.033 train accuracy: 0.984
# [30,   100/  469] train loss: 0.016 train accuracy: 1.000
# [30,   200/  469] train loss: 0.036 train accuracy: 0.984
# [30,   300/  469] train loss: 0.024 train accuracy: 0.992
# [30,   400/  469] train loss: 0.021 train accuracy: 0.992
# [31,   100/  469] train loss: 0.026 train accuracy: 0.992
# [31,   200/  469] train loss: 0.077 train accuracy: 0.977
# [31,   300/  469] train loss: 0.012 train accuracy: 1.000
# [31,   400/  469] train loss: 0.058 train accuracy: 0.992
# [32,   100/  469] train loss: 0.027 train accuracy: 1.000
# [32,   200/  469] train loss: 0.023 train accuracy: 0.992
# [32,   300/  469] train loss: 0.040 train accuracy: 0.984
# [32,   400/  469] train loss: 0.010 train accuracy: 1.000
# [33,   100/  469] train loss: 0.024 train accuracy: 0.992
# [33,   200/  469] train loss: 0.068 train accuracy: 0.992
# [33,   300/  469] train loss: 0.019 train accuracy: 0.992
# [33,   400/  469] train loss: 0.029 train accuracy: 0.984
# [34,   100/  469] train loss: 0.032 train accuracy: 0.992
# [34,   200/  469] train loss: 0.010 train accuracy: 1.000
# [34,   300/  469] train loss: 0.074 train accuracy: 0.984
# [34,   400/  469] train loss: 0.043 train accuracy: 0.992
# [35,   100/  469] train loss: 0.052 train accuracy: 0.984
# [35,   200/  469] train loss: 0.075 train accuracy: 0.969
# [35,   300/  469] train loss: 0.062 train accuracy: 0.969
# [35,   400/  469] train loss: 0.043 train accuracy: 0.984
# [36,   100/  469] train loss: 0.094 train accuracy: 0.984
# [36,   200/  469] train loss: 0.034 train accuracy: 0.984
# [36,   300/  469] train loss: 0.057 train accuracy: 0.992
# [36,   400/  469] train loss: 0.017 train accuracy: 0.992
# [37,   100/  469] train loss: 0.070 train accuracy: 0.961
# [37,   200/  469] train loss: 0.046 train accuracy: 0.984
# [37,   300/  469] train loss: 0.028 train accuracy: 0.984
# [37,   400/  469] train loss: 0.006 train accuracy: 1.000
# [38,   100/  469] train loss: 0.017 train accuracy: 1.000
# [38,   200/  469] train loss: 0.096 train accuracy: 0.977
# [38,   300/  469] train loss: 0.050 train accuracy: 0.992
# [38,   400/  469] train loss: 0.017 train accuracy: 0.992
# [39,   100/  469] train loss: 0.019 train accuracy: 0.992
# [39,   200/  469] train loss: 0.032 train accuracy: 0.984
# [39,   300/  469] train loss: 0.137 train accuracy: 0.961
# [39,   400/  469] train loss: 0.071 train accuracy: 0.953
# [40,   100/  469] train loss: 0.077 train accuracy: 0.977
# [40,   200/  469] train loss: 0.046 train accuracy: 0.992
# [40,   300/  469] train loss: 0.016 train accuracy: 1.000
# [40,   400/  469] train loss: 0.026 train accuracy: 0.992
# [41,   100/  469] train loss: 0.056 train accuracy: 0.992
# [41,   200/  469] train loss: 0.029 train accuracy: 0.992
# [41,   300/  469] train loss: 0.008 train accuracy: 1.000
# [41,   400/  469] train loss: 0.028 train accuracy: 0.992
# [42,   100/  469] train loss: 0.044 train accuracy: 0.984
# [42,   200/  469] train loss: 0.019 train accuracy: 0.992
# [42,   300/  469] train loss: 0.007 train accuracy: 1.000
# [42,   400/  469] train loss: 0.009 train accuracy: 1.000
# [43,   100/  469] train loss: 0.022 train accuracy: 0.992
# [43,   200/  469] train loss: 0.039 train accuracy: 0.984
# [43,   300/  469] train loss: 0.015 train accuracy: 1.000
# [43,   400/  469] train loss: 0.015 train accuracy: 1.000
# [44,   100/  469] train loss: 0.024 train accuracy: 0.992
# [44,   200/  469] train loss: 0.013 train accuracy: 1.000
# [44,   300/  469] train loss: 0.019 train accuracy: 0.992
# [44,   400/  469] train loss: 0.028 train accuracy: 0.992
# [45,   100/  469] train loss: 0.029 train accuracy: 0.984
# [45,   200/  469] train loss: 0.036 train accuracy: 0.992
# [45,   300/  469] train loss: 0.021 train accuracy: 0.992
# [45,   400/  469] train loss: 0.026 train accuracy: 0.984
# [46,   100/  469] train loss: 0.016 train accuracy: 1.000
# [46,   200/  469] train loss: 0.025 train accuracy: 0.992
# [46,   300/  469] train loss: 0.044 train accuracy: 0.984
# [46,   400/  469] train loss: 0.055 train accuracy: 0.977
# [47,   100/  469] train loss: 0.054 train accuracy: 0.984
# [47,   200/  469] train loss: 0.018 train accuracy: 0.992
# [47,   300/  469] train loss: 0.066 train accuracy: 0.977
# [47,   400/  469] train loss: 0.020 train accuracy: 0.992
# [48,   100/  469] train loss: 0.030 train accuracy: 0.992
# [48,   200/  469] train loss: 0.025 train accuracy: 0.992
# [48,   300/  469] train loss: 0.029 train accuracy: 0.992
# [48,   400/  469] train loss: 0.064 train accuracy: 0.984
# [49,   100/  469] train loss: 0.015 train accuracy: 1.000
# [49,   200/  469] train loss: 0.029 train accuracy: 0.984
# [49,   300/  469] train loss: 0.015 train accuracy: 1.000
# [49,   400/  469] train loss: 0.063 train accuracy: 0.984
# [50,   100/  469] train loss: 0.042 train accuracy: 0.984
# [50,   200/  469] train loss: 0.039 train accuracy: 0.992
# [50,   300/  469] train loss: 0.083 train accuracy: 0.961
# [50,   400/  469] train loss: 0.014 train accuracy: 0.992
# [51,   100/  469] train loss: 0.019 train accuracy: 1.000
# [51,   200/  469] train loss: 0.043 train accuracy: 0.984
# [51,   300/  469] train loss: 0.018 train accuracy: 0.992
# [51,   400/  469] train loss: 0.032 train accuracy: 0.992
# [52,   100/  469] train loss: 0.025 train accuracy: 0.992
# [52,   200/  469] train loss: 0.071 train accuracy: 0.969
# [52,   300/  469] train loss: 0.039 train accuracy: 0.992
# [52,   400/  469] train loss: 0.073 train accuracy: 0.984
# [53,   100/  469] train loss: 0.017 train accuracy: 1.000
# [53,   200/  469] train loss: 0.032 train accuracy: 0.984
# [53,   300/  469] train loss: 0.070 train accuracy: 0.961
# [53,   400/  469] train loss: 0.038 train accuracy: 0.992
# [54,   100/  469] train loss: 0.033 train accuracy: 0.984
# [54,   200/  469] train loss: 0.056 train accuracy: 0.984
# [54,   300/  469] train loss: 0.023 train accuracy: 1.000
# [54,   400/  469] train loss: 0.078 train accuracy: 0.977
# [55,   100/  469] train loss: 0.041 train accuracy: 0.984
# [55,   200/  469] train loss: 0.040 train accuracy: 0.984
# [55,   300/  469] train loss: 0.035 train accuracy: 0.977
# [55,   400/  469] train loss: 0.031 train accuracy: 0.992
# [56,   100/  469] train loss: 0.014 train accuracy: 1.000
# [56,   200/  469] train loss: 0.023 train accuracy: 1.000
# [56,   300/  469] train loss: 0.019 train accuracy: 1.000
# [56,   400/  469] train loss: 0.021 train accuracy: 1.000
# [57,   100/  469] train loss: 0.013 train accuracy: 1.000
# [57,   200/  469] train loss: 0.038 train accuracy: 0.984
# [57,   300/  469] train loss: 0.034 train accuracy: 0.992
# [57,   400/  469] train loss: 0.030 train accuracy: 0.992
# [58,   100/  469] train loss: 0.021 train accuracy: 0.992
# [58,   200/  469] train loss: 0.011 train accuracy: 1.000
# [58,   300/  469] train loss: 0.020 train accuracy: 0.992
# [58,   400/  469] train loss: 0.020 train accuracy: 1.000
# [59,   100/  469] train loss: 0.044 train accuracy: 0.984
# [59,   200/  469] train loss: 0.044 train accuracy: 0.984
# [59,   300/  469] train loss: 0.024 train accuracy: 0.992
# [59,   400/  469] train loss: 0.026 train accuracy: 0.992
# [60,   100/  469] train loss: 0.036 train accuracy: 0.969
# [60,   200/  469] train loss: 0.022 train accuracy: 0.984
# [60,   300/  469] train loss: 0.027 train accuracy: 0.984
# [60,   400/  469] train loss: 0.030 train accuracy: 0.984

# %%
# Calculate test accuracy
_, test_accuracy = utils.getLossAccuracyOnDataset(teacher_net, test_loader, fast_device)
print('test accuracy: ', test_accuracy)
# Out:
# test accuracy:  0.9892
