# %% [markdown]
# ### Import required packages and limit GPU usage

# %%
import numpy as np
import math

# %matplotlib inline
import matplotlib.pyplot as plt

import pickle
import argparse
import time
import itertools
from copy import deepcopy
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import networks
import utils
    
# %load_ext autoreload
# %autoreload 2

# %%
use_gpu = True    # set use_gpu to True if system has gpu
gpu_id = 2        # id of gpu to be used
cpu_device = torch.device('cpu')
# fast_device is where computation (training, inference) happens
fast_device = torch.device('cpu')
if use_gpu:
    os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2'    # set visible devices depending on system configuration
    fast_device = torch.device('cuda:' + str(gpu_id))

# %%
# Ensure reproducibility
def reproducibilitySeed():
    """
    Ensure reproducibility of results; Seeds to 0
    """
    torch_init_seed = 0
    torch.manual_seed(torch_init_seed)
    numpy_init_seed = 0
    np.random.seed(numpy_init_seed)
    if use_gpu:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

reproducibilitySeed()

# %% [markdown]
# ### Load dataset

# %%
import torchvision
import torchvision.transforms as transforms

# Student trained without data augmentation
transform = transforms.Compose(
                [
                    transforms.ToTensor(),
                    transforms.Normalize((0.5, 0.5), (0.5, 0.5))
                ]
            )

train_val_dataset = torchvision.datasets.MNIST(root='./MNIST_dataset/', train=True, 
                                            download=True, transform=transform)

test_dataset = torchvision.datasets.MNIST(root='./MNIST_dataset/', train=False, 
                                            download=True, transform=transform)

num_train = int(1.0 * len(train_val_dataset) * 95 / 100)
num_val = len(train_val_dataset) - num_train
train_dataset, val_dataset = torch.utils.data.random_split(train_val_dataset, [num_train, num_val])

batch_size = 128
train_val_loader = torch.utils.data.DataLoader(train_val_dataset, batch_size=128, shuffle=True, num_workers=2)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=128, shuffle=False, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=2)

# %%
checkpoints_path_teacher = 'checkpoints_teacher/'
checkpoints_path_student = 'checkpoints_student/'
if not os.path.exists(checkpoints_path_student):
    os.makedirs(checkpoints_path_student)

# %% [markdown]
# ### Load teacher network

# %%
# set the hparams used for training teacher to load the teacher network
learning_rates = [1e-2]
learning_rate_decays = [0.95]
weight_decays = [1e-5]
momentums = [0.9]
# keeping dropout input = dropout hidden
dropout_probabilities = [(0.0, 0.0)]
hparams_list = []
for hparam_tuple in itertools.product(dropout_probabilities, weight_decays, learning_rate_decays, 
                                        momentums, learning_rates):
    hparam = {}
    hparam['dropout_input'] = hparam_tuple[0][0]
    hparam['dropout_hidden'] = hparam_tuple[0][1]
    hparam['weight_decay'] = hparam_tuple[1]
    hparam['lr_decay'] = hparam_tuple[2]
    hparam['momentum'] = hparam_tuple[3]
    hparam['lr'] = hparam_tuple[4]
    hparams_list.append(hparam)
    
load_path = checkpoints_path_teacher + utils.hparamToString(hparams_list[0]) + '_final.tar'
teacher_net = networks.TeacherNetwork()
teacher_net.load_state_dict(torch.load(load_path, map_location=fast_device)['model_state_dict'])
teacher_net = teacher_net.to(fast_device)

# %%
# Calculate teacher test accuracy
_, test_accuracy = utils.getLossAccuracyOnDataset(teacher_net, test_loader, fast_device)
print('teacher test accuracy: ', test_accuracy)
# Out:
# teacher test accuracy:  0.9892

# %% [markdown]
# ### Train student network without distillation

# %%
num_epochs = 60
print_every = 100

# %%
temperatures = [1]    # temperature for distillation loss
# trade-off between soft-target (st) cross-entropy and true-target (tt) cross-entropy;
# loss = alpha * st + (1 - alpha) * tt
alphas = [0.0]
learning_rates = [1e-2]
learning_rate_decays = [0.95]
weight_decays = [1e-5]
momentums = [0.9]
# No dropout used
dropout_probabilities = [(0.0, 0.0)]
hparams_list = []
for hparam_tuple in itertools.product(alphas, temperatures, dropout_probabilities, weight_decays, learning_rate_decays, 
                                        momentums, learning_rates):
    hparam = {}
    hparam['alpha'] = hparam_tuple[0]
    hparam['T'] = hparam_tuple[1]
    hparam['dropout_input'] = hparam_tuple[2][0]
    hparam['dropout_hidden'] = hparam_tuple[2][1]
    hparam['weight_decay'] = hparam_tuple[3]
    hparam['lr_decay'] = hparam_tuple[4]
    hparam['momentum'] = hparam_tuple[5]
    hparam['lr'] = hparam_tuple[6]
    hparams_list.append(hparam)

results_no_distill = {}
for hparam in hparams_list:
    print('Training with hparams' + utils.hparamToString(hparam))
    reproducibilitySeed()
    student_net = networks.StudentNetwork()
    student_net = student_net.to(fast_device)
    hparam_tuple = utils.hparamDictToTuple(hparam)
    results_no_distill[hparam_tuple] = utils.trainStudentOnHparam(teacher_net, student_net, hparam, num_epochs, 
                                                                    train_val_loader, None, 
                                                                    print_every=print_every, 
                                                                    fast_device=fast_device)
    save_path = checkpoints_path_student + utils.hparamToString(hparam) + '_final.tar'
    torch.save({'results' : results_no_distill[hparam_tuple], 
                'model_state_dict' : student_net.state_dict(), 
                'epoch' : num_epochs}, save_path)
# Out:
# Training with hparamsT=1, alpha=0.0, dropout_hidden=0.0, dropout_input=0.0, lr=0.01, lr_decay=0.95, momentum=0.9, weight_decay=1e-05
# [1,   100/  469] train loss: 0.426 train accuracy: 0.875
# [1,   200/  469] train loss: 0.326 train accuracy: 0.898
# [1,   300/  469] train loss: 0.229 train accuracy: 0.945
# [1,   400/  469] train loss: 0.232 train accuracy: 0.922
# [2,   100/  469] train loss: 0.245 train accuracy: 0.938
# [2,   200/  469] train loss: 0.216 train accuracy: 0.945
# [2,   300/  469] train loss: 0.134 train accuracy: 0.984
# [2,   400/  469] train loss: 0.201 train accuracy: 0.961
# [3,   100/  469] train loss: 0.108 train accuracy: 0.977
# [3,   200/  469] train loss: 0.119 train accuracy: 0.961
# [3,   300/  469] train loss: 0.151 train accuracy: 0.969
# [3,   400/  469] train loss: 0.189 train accuracy: 0.945
# [4,   100/  469] train loss: 0.191 train accuracy: 0.945
# [4,   200/  469] train loss: 0.259 train accuracy: 0.938
# [4,   300/  469] train loss: 0.141 train accuracy: 0.977
# [4,   400/  469] train loss: 0.095 train accuracy: 0.984
# [5,   100/  469] train loss: 0.235 train accuracy: 0.953
# [5,   200/  469] train loss: 0.070 train accuracy: 0.984
# [5,   300/  469] train loss: 0.072 train accuracy: 0.977
# [5,   400/  469] train loss: 0.166 train accuracy: 0.930
# [6,   100/  469] train loss: 0.175 train accuracy: 0.953
# [6,   200/  469] train loss: 0.113 train accuracy: 0.969
# [6,   300/  469] train loss: 0.111 train accuracy: 0.977
# [6,   400/  469] train loss: 0.245 train accuracy: 0.945
# [7,   100/  469] train loss: 0.127 train accuracy: 0.984
# [7,   200/  469] train loss: 0.058 train accuracy: 0.992
# [7,   300/  469] train loss: 0.045 train accuracy: 0.984
# [7,   400/  469] train loss: 0.084 train accuracy: 0.984
# [8,   100/  469] train loss: 0.116 train accuracy: 0.977
# [8,   200/  469] train loss: 0.057 train accuracy: 0.992
# [8,   300/  469] train loss: 0.060 train accuracy: 0.977
# [8,   400/  469] train loss: 0.037 train accuracy: 0.992
# [9,   100/  469] train loss: 0.028 train accuracy: 1.000
# [9,   200/  469] train loss: 0.174 train accuracy: 0.953
# [9,   300/  469] train loss: 0.029 train accuracy: 0.984
# [9,   400/  469] train loss: 0.071 train accuracy: 1.000
# [10,   100/  469] train loss: 0.045 train accuracy: 0.992
# [10,   200/  469] train loss: 0.033 train accuracy: 0.992
# [10,   300/  469] train loss: 0.041 train accuracy: 0.992
# [10,   400/  469] train loss: 0.037 train accuracy: 1.000
# [11,   100/  469] train loss: 0.130 train accuracy: 0.953
# [11,   200/  469] train loss: 0.049 train accuracy: 0.984
# [11,   300/  469] train loss: 0.023 train accuracy: 1.000
# [11,   400/  469] train loss: 0.055 train accuracy: 0.992
# [12,   100/  469] train loss: 0.107 train accuracy: 0.961
# [12,   200/  469] train loss: 0.040 train accuracy: 0.984
# [12,   300/  469] train loss: 0.029 train accuracy: 0.992
# [12,   400/  469] train loss: 0.024 train accuracy: 1.000
# [13,   100/  469] train loss: 0.081 train accuracy: 0.984
# [13,   200/  469] train loss: 0.076 train accuracy: 0.984
# [13,   300/  469] train loss: 0.138 train accuracy: 0.961
# [13,   400/  469] train loss: 0.036 train accuracy: 0.992
# [14,   100/  469] train loss: 0.051 train accuracy: 0.992
# [14,   200/  469] train loss: 0.045 train accuracy: 0.984
# [14,   300/  469] train loss: 0.043 train accuracy: 0.984
# [14,   400/  469] train loss: 0.058 train accuracy: 0.984
# [15,   100/  469] train loss: 0.034 train accuracy: 0.992
# [15,   200/  469] train loss: 0.020 train accuracy: 1.000
# [15,   300/  469] train loss: 0.020 train accuracy: 1.000
# [15,   400/  469] train loss: 0.036 train accuracy: 0.984
# [16,   100/  469] train loss: 0.030 train accuracy: 0.984
# [16,   200/  469] train loss: 0.016 train accuracy: 1.000
# [16,   300/  469] train loss: 0.022 train accuracy: 0.992
# [16,   400/  469] train loss: 0.048 train accuracy: 0.984
# [17,   100/  469] train loss: 0.031 train accuracy: 0.992
# [17,   200/  469] train loss: 0.034 train accuracy: 0.984
# [17,   300/  469] train loss: 0.104 train accuracy: 0.977
# [17,   400/  469] train loss: 0.031 train accuracy: 0.992
# [18,   100/  469] train loss: 0.053 train accuracy: 0.977
# [18,   200/  469] train loss: 0.049 train accuracy: 0.992
# [18,   300/  469] train loss: 0.041 train accuracy: 0.992
# [18,   400/  469] train loss: 0.054 train accuracy: 0.977
# [19,   100/  469] train loss: 0.019 train accuracy: 1.000
# [19,   200/  469] train loss: 0.029 train accuracy: 1.000
# [19,   300/  469] train loss: 0.019 train accuracy: 1.000
# [19,   400/  469] train loss: 0.029 train accuracy: 0.992
# [20,   100/  469] train loss: 0.023 train accuracy: 0.992
# [20,   200/  469] train loss: 0.018 train accuracy: 1.000
# [20,   300/  469] train loss: 0.039 train accuracy: 0.992
# [20,   400/  469] train loss: 0.042 train accuracy: 0.992
# [21,   100/  469] train loss: 0.040 train accuracy: 0.984
# [21,   200/  469] train loss: 0.019 train accuracy: 1.000
# [21,   300/  469] train loss: 0.028 train accuracy: 1.000
# [21,   400/  469] train loss: 0.050 train accuracy: 0.984
# [22,   100/  469] train loss: 0.018 train accuracy: 1.000
# [22,   200/  469] train loss: 0.029 train accuracy: 0.992
# [22,   300/  469] train loss: 0.057 train accuracy: 0.977
# [22,   400/  469] train loss: 0.017 train accuracy: 1.000
# [23,   100/  469] train loss: 0.017 train accuracy: 1.000
# [23,   200/  469] train loss: 0.032 train accuracy: 0.992
# [23,   300/  469] train loss: 0.046 train accuracy: 0.984
# [23,   400/  469] train loss: 0.015 train accuracy: 1.000
# [24,   100/  469] train loss: 0.008 train accuracy: 1.000
# [24,   200/  469] train loss: 0.019 train accuracy: 1.000
# [24,   300/  469] train loss: 0.045 train accuracy: 0.992
# [24,   400/  469] train loss: 0.025 train accuracy: 0.992
# [25,   100/  469] train loss: 0.031 train accuracy: 1.000
# [25,   200/  469] train loss: 0.029 train accuracy: 0.992
# [25,   300/  469] train loss: 0.016 train accuracy: 1.000
# [25,   400/  469] train loss: 0.025 train accuracy: 1.000
# [26,   100/  469] train loss: 0.043 train accuracy: 0.992
# [26,   200/  469] train loss: 0.042 train accuracy: 0.984
# [26,   300/  469] train loss: 0.028 train accuracy: 0.992
# [26,   400/  469] train loss: 0.011 train accuracy: 1.000
# [27,   100/  469] train loss: 0.008 train accuracy: 1.000
# [27,   200/  469] train loss: 0.073 train accuracy: 0.992
# [27,   300/  469] train loss: 0.008 train accuracy: 1.000
# [27,   400/  469] train loss: 0.031 train accuracy: 0.992
# [28,   100/  469] train loss: 0.013 train accuracy: 1.000
# [28,   200/  469] train loss: 0.022 train accuracy: 1.000
# [28,   300/  469] train loss: 0.013 train accuracy: 1.000
# [28,   400/  469] train loss: 0.020 train accuracy: 1.000
# [29,   100/  469] train loss: 0.028 train accuracy: 0.992
# [29,   200/  469] train loss: 0.019 train accuracy: 1.000
# [29,   300/  469] train loss: 0.032 train accuracy: 0.992
# [29,   400/  469] train loss: 0.024 train accuracy: 0.992
# [30,   100/  469] train loss: 0.027 train accuracy: 0.992
# [30,   200/  469] train loss: 0.019 train accuracy: 0.992
# [30,   300/  469] train loss: 0.053 train accuracy: 0.992
# [30,   400/  469] train loss: 0.016 train accuracy: 1.000
# [31,   100/  469] train loss: 0.034 train accuracy: 0.992
# [31,   200/  469] train loss: 0.015 train accuracy: 1.000
# [31,   300/  469] train loss: 0.049 train accuracy: 0.992
# [31,   400/  469] train loss: 0.023 train accuracy: 1.000
# [32,   100/  469] train loss: 0.018 train accuracy: 1.000
# [32,   200/  469] train loss: 0.031 train accuracy: 1.000
# [32,   300/  469] train loss: 0.021 train accuracy: 1.000
# [32,   400/  469] train loss: 0.009 train accuracy: 1.000
# [33,   100/  469] train loss: 0.013 train accuracy: 0.992
# [33,   200/  469] train loss: 0.019 train accuracy: 1.000
# [33,   300/  469] train loss: 0.031 train accuracy: 1.000
# [33,   400/  469] train loss: 0.007 train accuracy: 1.000
# [34,   100/  469] train loss: 0.016 train accuracy: 0.992
# [34,   200/  469] train loss: 0.015 train accuracy: 1.000
# [34,   300/  469] train loss: 0.011 train accuracy: 1.000
# [34,   400/  469] train loss: 0.024 train accuracy: 0.992
# [35,   100/  469] train loss: 0.024 train accuracy: 1.000
# [35,   200/  469] train loss: 0.052 train accuracy: 0.992
# [35,   300/  469] train loss: 0.040 train accuracy: 0.977
# [35,   400/  469] train loss: 0.043 train accuracy: 0.977
# [36,   100/  469] train loss: 0.019 train accuracy: 1.000
# [36,   200/  469] train loss: 0.020 train accuracy: 0.992
# [36,   300/  469] train loss: 0.027 train accuracy: 0.992
# [36,   400/  469] train loss: 0.023 train accuracy: 1.000
# [37,   100/  469] train loss: 0.047 train accuracy: 0.984
# [37,   200/  469] train loss: 0.035 train accuracy: 0.984
# [37,   300/  469] train loss: 0.010 train accuracy: 1.000
# [37,   400/  469] train loss: 0.056 train accuracy: 0.984
# [38,   100/  469] train loss: 0.044 train accuracy: 0.984
# [38,   200/  469] train loss: 0.023 train accuracy: 0.992
# [38,   300/  469] train loss: 0.037 train accuracy: 0.984
# [38,   400/  469] train loss: 0.029 train accuracy: 0.992
# [39,   100/  469] train loss: 0.008 train accuracy: 1.000
# [39,   200/  469] train loss: 0.017 train accuracy: 1.000
# [39,   300/  469] train loss: 0.044 train accuracy: 0.992
# [39,   400/  469] train loss: 0.014 train accuracy: 1.000
# [40,   100/  469] train loss: 0.052 train accuracy: 0.984
# [40,   200/  469] train loss: 0.016 train accuracy: 1.000
# [40,   300/  469] train loss: 0.011 train accuracy: 1.000
# [40,   400/  469] train loss: 0.016 train accuracy: 1.000
# [41,   100/  469] train loss: 0.015 train accuracy: 1.000
# [41,   200/  469] train loss: 0.028 train accuracy: 0.992
# [41,   300/  469] train loss: 0.008 train accuracy: 1.000
# [41,   400/  469] train loss: 0.010 train accuracy: 1.000
# [42,   100/  469] train loss: 0.019 train accuracy: 1.000
# [42,   200/  469] train loss: 0.010 train accuracy: 1.000
# [42,   300/  469] train loss: 0.019 train accuracy: 0.992
# [42,   400/  469] train loss: 0.006 train accuracy: 1.000
# [43,   100/  469] train loss: 0.016 train accuracy: 0.992
# [43,   200/  469] train loss: 0.029 train accuracy: 0.992
# [43,   300/  469] train loss: 0.019 train accuracy: 1.000
# [43,   400/  469] train loss: 0.015 train accuracy: 1.000
# [44,   100/  469] train loss: 0.015 train accuracy: 1.000
# [44,   200/  469] train loss: 0.021 train accuracy: 0.992
# [44,   300/  469] train loss: 0.053 train accuracy: 0.977
# [44,   400/  469] train loss: 0.010 train accuracy: 1.000
# [45,   100/  469] train loss: 0.012 train accuracy: 1.000
# [45,   200/  469] train loss: 0.009 train accuracy: 1.000
# [45,   300/  469] train loss: 0.015 train accuracy: 1.000
# [45,   400/  469] train loss: 0.014 train accuracy: 1.000
# [46,   100/  469] train loss: 0.024 train accuracy: 1.000
# [46,   200/  469] train loss: 0.011 train accuracy: 1.000
# [46,   300/  469] train loss: 0.031 train accuracy: 0.992
# [46,   400/  469] train loss: 0.015 train accuracy: 1.000
# [47,   100/  469] train loss: 0.015 train accuracy: 1.000
# [47,   200/  469] train loss: 0.016 train accuracy: 1.000
# [47,   300/  469] train loss: 0.016 train accuracy: 0.992
# [47,   400/  469] train loss: 0.007 train accuracy: 1.000
# [48,   100/  469] train loss: 0.022 train accuracy: 1.000
# [48,   200/  469] train loss: 0.009 train accuracy: 1.000
# [48,   300/  469] train loss: 0.004 train accuracy: 1.000
# [48,   400/  469] train loss: 0.012 train accuracy: 1.000
# [49,   100/  469] train loss: 0.020 train accuracy: 0.992
# [49,   200/  469] train loss: 0.023 train accuracy: 0.992
# [49,   300/  469] train loss: 0.029 train accuracy: 0.992
# [49,   400/  469] train loss: 0.021 train accuracy: 1.000
# [50,   100/  469] train loss: 0.013 train accuracy: 1.000
# [50,   200/  469] train loss: 0.016 train accuracy: 1.000
# [50,   300/  469] train loss: 0.022 train accuracy: 0.992
# [50,   400/  469] train loss: 0.023 train accuracy: 0.992
# [51,   100/  469] train loss: 0.018 train accuracy: 0.992
# [51,   200/  469] train loss: 0.018 train accuracy: 1.000
# [51,   300/  469] train loss: 0.014 train accuracy: 1.000
# [51,   400/  469] train loss: 0.017 train accuracy: 1.000
# [52,   100/  469] train loss: 0.014 train accuracy: 1.000
# [52,   200/  469] train loss: 0.016 train accuracy: 1.000
# [52,   300/  469] train loss: 0.016 train accuracy: 1.000
# [52,   400/  469] train loss: 0.020 train accuracy: 0.992
# [53,   100/  469] train loss: 0.021 train accuracy: 0.992
# [53,   200/  469] train loss: 0.011 train accuracy: 1.000
# [53,   300/  469] train loss: 0.013 train accuracy: 1.000
# [53,   400/  469] train loss: 0.026 train accuracy: 0.992
# [54,   100/  469] train loss: 0.011 train accuracy: 1.000
# [54,   200/  469] train loss: 0.024 train accuracy: 0.992
# [54,   300/  469] train loss: 0.012 train accuracy: 1.000
# [54,   400/  469] train loss: 0.011 train accuracy: 1.000
# [55,   100/  469] train loss: 0.015 train accuracy: 1.000
# [55,   200/  469] train loss: 0.026 train accuracy: 0.984
# [55,   300/  469] train loss: 0.017 train accuracy: 1.000
# [55,   400/  469] train loss: 0.010 train accuracy: 1.000
# [56,   100/  469] train loss: 0.015 train accuracy: 0.992
# [56,   200/  469] train loss: 0.018 train accuracy: 1.000
# [56,   300/  469] train loss: 0.028 train accuracy: 0.984
# [56,   400/  469] train loss: 0.024 train accuracy: 0.992
# [57,   100/  469] train loss: 0.003 train accuracy: 1.000
# [57,   200/  469] train loss: 0.013 train accuracy: 1.000
# [57,   300/  469] train loss: 0.016 train accuracy: 1.000
# [57,   400/  469] train loss: 0.019 train accuracy: 1.000
# [58,   100/  469] train loss: 0.018 train accuracy: 0.992
# [58,   200/  469] train loss: 0.010 train accuracy: 1.000
# [58,   300/  469] train loss: 0.013 train accuracy: 1.000
# [58,   400/  469] train loss: 0.017 train accuracy: 0.992
# [59,   100/  469] train loss: 0.019 train accuracy: 1.000
# [59,   200/  469] train loss: 0.009 train accuracy: 1.000
# [59,   300/  469] train loss: 0.022 train accuracy: 0.992
# [59,   400/  469] train loss: 0.011 train accuracy: 1.000
# [60,   100/  469] train loss: 0.039 train accuracy: 0.992
# [60,   200/  469] train loss: 0.018 train accuracy: 1.000
# [60,   300/  469] train loss: 0.008 train accuracy: 1.000
# [60,   400/  469] train loss: 0.009 train accuracy: 1.000

# %%
# Calculate student test accuracy
_, test_accuracy = utils.getLossAccuracyOnDataset(student_net, test_loader, fast_device)
print('student test accuracy (w/o distillation): ', test_accuracy)
# Out:
# student test accuracy (w/o distillation):  0.9819

# %% [markdown]
# ### Hyperparameter search utils

# %%
# plt.rcParams['figure.figsize'] = [10, 5]
weight_decay_scatter = ([math.log10(h['weight_decay']) if h['weight_decay'] > 0 else -6 for h in hparams_list])
dropout_scatter = [int(h['dropout_input'] == 0.2) for h in hparams_list]
colors = []
for i in range(len(hparams_list)):
    cur_hparam_tuple = utils.hparamDictToTuple(hparams_list[i])
    colors.append(results_no_distill[cur_hparam_tuple]['val_acc'][-1])
    
marker_size = 100
fig, ax = plt.subplots()
plt.scatter(weight_decay_scatter, dropout_scatter, marker_size, c=colors, edgecolors='black')
plt.colorbar()
for i in range(len(weight_decay_scatter)):
    ax.annotate(str('%0.4f' % (colors[i], )), (weight_decay_scatter[i], dropout_scatter[i]))
plt.show()

# %% [markdown]
# ### Train student network using distillation

# %%
num_epochs = 60
print_every = 100

# %%
temperatures = [10]
# trade-off between soft-target (st) cross-entropy and true-target (tt) cross-entropy;
# loss = alpha * st + (1 - alpha) * tt
alphas = [0.5]
learning_rates = [1e-2]
learning_rate_decays = [0.95]
weight_decays = [1e-5]
momentums = [0.9]
dropout_probabilities = [(0.0, 0.0)]
hparams_list = []
for hparam_tuple in itertools.product(alphas, temperatures, dropout_probabilities, weight_decays, learning_rate_decays, 
                                        momentums, learning_rates):
    hparam = {}
    hparam['alpha'] = hparam_tuple[0]
    hparam['T'] = hparam_tuple[1]
    hparam['dropout_input'] = hparam_tuple[2][0]
    hparam['dropout_hidden'] = hparam_tuple[2][1]
    hparam['weight_decay'] = hparam_tuple[3]
    hparam['lr_decay'] = hparam_tuple[4]
    hparam['momentum'] = hparam_tuple[5]
    hparam['lr'] = hparam_tuple[6]
    hparams_list.append(hparam)

results_distill = {}
for hparam in hparams_list:
    print('Training with hparams' + utils.hparamToString(hparam))
    reproducibilitySeed()
    student_net = networks.StudentNetwork()
    student_net = student_net.to(fast_device)
    hparam_tuple = utils.hparamDictToTuple(hparam)
    results_distill[hparam_tuple] = utils.trainStudentOnHparam(teacher_net, student_net, hparam, num_epochs, 
                                                                train_val_loader, None, 
                                                                print_every=print_every, 
                                                                fast_device=fast_device)
    save_path = checkpoints_path_student + utils.hparamToString(hparam) + '_final.tar'
    torch.save({'results' : results_distill[hparam_tuple], 
                'model_state_dict' : student_net.state_dict(), 
                'epoch' : num_epochs}, save_path)
# Out:
# Training with hparamsT=10, alpha=0.5, dropout_hidden=0.0, dropout_input=0.0, lr=0.01, lr_decay=0.95, momentum=0.9, weight_decay=1e-05
# [1,   100/  469] train loss: 1.911 train accuracy: 0.891
# [1,   200/  469] train loss: 1.322 train accuracy: 0.930
# [1,   300/  469] train loss: 1.071 train accuracy: 0.969
# [1,   400/  469] train loss: 0.722 train accuracy: 0.953
# [2,   100/  469] train loss: 0.664 train accuracy: 0.961
# [2,   200/  469] train loss: 0.582 train accuracy: 0.953
# [2,   300/  469] train loss: 0.429 train accuracy: 0.984
# [2,   400/  469] train loss: 0.480 train accuracy: 0.961
# [3,   100/  469] train loss: 0.351 train accuracy: 0.992
# [3,   200/  469] train loss: 0.297 train accuracy: 1.000
# [3,   300/  469] train loss: 0.310 train accuracy: 0.984
# [3,   400/  469] train loss: 0.308 train accuracy: 0.992
# [4,   100/  469] train loss: 0.246 train accuracy: 0.977
# [4,   200/  469] train loss: 0.321 train accuracy: 0.969
# [4,   300/  469] train loss: 0.250 train accuracy: 0.984
# [4,   400/  469] train loss: 0.210 train accuracy: 0.992
# [5,   100/  469] train loss: 0.241 train accuracy: 0.969
# [5,   200/  469] train loss: 0.197 train accuracy: 1.000
# [5,   300/  469] train loss: 0.183 train accuracy: 1.000
# [5,   400/  469] train loss: 0.173 train accuracy: 0.984
# [6,   100/  469] train loss: 0.201 train accuracy: 0.953
# [6,   200/  469] train loss: 0.181 train accuracy: 0.984
# [6,   300/  469] train loss: 0.162 train accuracy: 0.984
# [6,   400/  469] train loss: 0.227 train accuracy: 0.969
# [7,   100/  469] train loss: 0.186 train accuracy: 0.984
# [7,   200/  469] train loss: 0.137 train accuracy: 0.984
# [7,   300/  469] train loss: 0.145 train accuracy: 1.000
# [7,   400/  469] train loss: 0.155 train accuracy: 0.992
# [8,   100/  469] train loss: 0.167 train accuracy: 0.977
# [8,   200/  469] train loss: 0.126 train accuracy: 0.992
# [8,   300/  469] train loss: 0.125 train accuracy: 1.000
# [8,   400/  469] train loss: 0.130 train accuracy: 0.992
# [9,   100/  469] train loss: 0.139 train accuracy: 1.000
# [9,   200/  469] train loss: 0.155 train accuracy: 0.969
# [9,   300/  469] train loss: 0.112 train accuracy: 1.000
# [9,   400/  469] train loss: 0.128 train accuracy: 1.000
# [10,   100/  469] train loss: 0.117 train accuracy: 0.992
# [10,   200/  469] train loss: 0.102 train accuracy: 0.992
# [10,   300/  469] train loss: 0.113 train accuracy: 0.984
# [10,   400/  469] train loss: 0.110 train accuracy: 1.000
# [11,   100/  469] train loss: 0.152 train accuracy: 0.977
# [11,   200/  469] train loss: 0.108 train accuracy: 1.000
# [11,   300/  469] train loss: 0.110 train accuracy: 1.000
# [11,   400/  469] train loss: 0.137 train accuracy: 0.984
# [12,   100/  469] train loss: 0.130 train accuracy: 0.992
# [12,   200/  469] train loss: 0.122 train accuracy: 0.984
# [12,   300/  469] train loss: 0.106 train accuracy: 0.992
# [12,   400/  469] train loss: 0.095 train accuracy: 1.000
# [13,   100/  469] train loss: 0.142 train accuracy: 0.977
# [13,   200/  469] train loss: 0.122 train accuracy: 0.992
# [13,   300/  469] train loss: 0.139 train accuracy: 0.977
# [13,   400/  469] train loss: 0.114 train accuracy: 0.992
# [14,   100/  469] train loss: 0.114 train accuracy: 0.977
# [14,   200/  469] train loss: 0.103 train accuracy: 0.984
# [14,   300/  469] train loss: 0.116 train accuracy: 1.000
# [14,   400/  469] train loss: 0.102 train accuracy: 0.992
# [15,   100/  469] train loss: 0.109 train accuracy: 0.992
# [15,   200/  469] train loss: 0.100 train accuracy: 0.992
# [15,   300/  469] train loss: 0.098 train accuracy: 1.000
# [15,   400/  469] train loss: 0.090 train accuracy: 0.992
# [16,   100/  469] train loss: 0.095 train accuracy: 1.000
# [16,   200/  469] train loss: 0.097 train accuracy: 0.992
# [16,   300/  469] train loss: 0.081 train accuracy: 1.000
# [16,   400/  469] train loss: 0.091 train accuracy: 0.992
# [17,   100/  469] train loss: 0.084 train accuracy: 1.000
# [17,   200/  469] train loss: 0.102 train accuracy: 1.000
# [17,   300/  469] train loss: 0.111 train accuracy: 0.969
# [17,   400/  469] train loss: 0.087 train accuracy: 1.000
# [18,   100/  469] train loss: 0.105 train accuracy: 0.984
# [18,   200/  469] train loss: 0.114 train accuracy: 0.977
# [18,   300/  469] train loss: 0.098 train accuracy: 0.992
# [18,   400/  469] train loss: 0.105 train accuracy: 0.977
# [19,   100/  469] train loss: 0.085 train accuracy: 1.000
# [19,   200/  469] train loss: 0.095 train accuracy: 0.992
# [19,   300/  469] train loss: 0.099 train accuracy: 1.000
# [19,   400/  469] train loss: 0.080 train accuracy: 1.000
# [20,   100/  469] train loss: 0.078 train accuracy: 0.992
# [20,   200/  469] train loss: 0.080 train accuracy: 0.984
# [20,   300/  469] train loss: 0.096 train accuracy: 0.992
# [20,   400/  469] train loss: 0.091 train accuracy: 0.992
# [21,   100/  469] train loss: 0.081 train accuracy: 0.992
# [21,   200/  469] train loss: 0.076 train accuracy: 1.000
# [21,   300/  469] train loss: 0.093 train accuracy: 0.984
# [21,   400/  469] train loss: 0.075 train accuracy: 0.992
# [22,   100/  469] train loss: 0.087 train accuracy: 1.000
# [22,   200/  469] train loss: 0.075 train accuracy: 1.000
# [22,   300/  469] train loss: 0.088 train accuracy: 1.000
# [22,   400/  469] train loss: 0.073 train accuracy: 1.000
# [23,   100/  469] train loss: 0.088 train accuracy: 0.992
# [23,   200/  469] train loss: 0.089 train accuracy: 0.984
# [23,   300/  469] train loss: 0.100 train accuracy: 0.984
# [23,   400/  469] train loss: 0.093 train accuracy: 0.992
# [24,   100/  469] train loss: 0.065 train accuracy: 1.000
# [24,   200/  469] train loss: 0.074 train accuracy: 1.000
# [24,   300/  469] train loss: 0.116 train accuracy: 0.984
# [24,   400/  469] train loss: 0.082 train accuracy: 0.984
# [25,   100/  469] train loss: 0.092 train accuracy: 0.992
# [25,   200/  469] train loss: 0.076 train accuracy: 1.000
# [25,   300/  469] train loss: 0.079 train accuracy: 1.000
# [25,   400/  469] train loss: 0.072 train accuracy: 1.000
# [26,   100/  469] train loss: 0.102 train accuracy: 0.984
# [26,   200/  469] train loss: 0.099 train accuracy: 1.000
# [26,   300/  469] train loss: 0.078 train accuracy: 0.992
# [26,   400/  469] train loss: 0.073 train accuracy: 1.000
# [27,   100/  469] train loss: 0.066 train accuracy: 1.000
# [27,   200/  469] train loss: 0.101 train accuracy: 0.992
# [27,   300/  469] train loss: 0.070 train accuracy: 1.000
# [27,   400/  469] train loss: 0.083 train accuracy: 0.992
# [28,   100/  469] train loss: 0.062 train accuracy: 1.000
# [28,   200/  469] train loss: 0.069 train accuracy: 1.000
# [28,   300/  469] train loss: 0.071 train accuracy: 0.992
# [28,   400/  469] train loss: 0.078 train accuracy: 0.992
# [29,   100/  469] train loss: 0.084 train accuracy: 0.992
# [29,   200/  469] train loss: 0.079 train accuracy: 0.992
# [29,   300/  469] train loss: 0.093 train accuracy: 0.992
# [29,   400/  469] train loss: 0.083 train accuracy: 0.992
# [30,   100/  469] train loss: 0.080 train accuracy: 1.000
# [30,   200/  469] train loss: 0.073 train accuracy: 1.000
# [30,   300/  469] train loss: 0.089 train accuracy: 0.984
# [30,   400/  469] train loss: 0.070 train accuracy: 1.000
# [31,   100/  469] train loss: 0.078 train accuracy: 0.992
# [31,   200/  469] train loss: 0.078 train accuracy: 0.992
# [31,   300/  469] train loss: 0.116 train accuracy: 0.977
# [31,   400/  469] train loss: 0.066 train accuracy: 1.000
# [32,   100/  469] train loss: 0.076 train accuracy: 0.992
# [32,   200/  469] train loss: 0.081 train accuracy: 1.000
# [32,   300/  469] train loss: 0.074 train accuracy: 1.000
# [32,   400/  469] train loss: 0.062 train accuracy: 1.000
# [33,   100/  469] train loss: 0.067 train accuracy: 1.000
# [33,   200/  469] train loss: 0.067 train accuracy: 0.992
# [33,   300/  469] train loss: 0.081 train accuracy: 1.000
# [33,   400/  469] train loss: 0.064 train accuracy: 1.000
# [34,   100/  469] train loss: 0.100 train accuracy: 0.992
# [34,   200/  469] train loss: 0.065 train accuracy: 1.000
# [34,   300/  469] train loss: 0.080 train accuracy: 0.992
# [34,   400/  469] train loss: 0.097 train accuracy: 0.984
# [35,   100/  469] train loss: 0.069 train accuracy: 1.000
# [35,   200/  469] train loss: 0.078 train accuracy: 0.984
# [35,   300/  469] train loss: 0.076 train accuracy: 0.992
# [35,   400/  469] train loss: 0.093 train accuracy: 0.984
# [36,   100/  469] train loss: 0.065 train accuracy: 1.000
# [36,   200/  469] train loss: 0.066 train accuracy: 1.000
# [36,   300/  469] train loss: 0.079 train accuracy: 0.992
# [36,   400/  469] train loss: 0.068 train accuracy: 1.000
# [37,   100/  469] train loss: 0.088 train accuracy: 0.984
# [37,   200/  469] train loss: 0.078 train accuracy: 0.984
# [37,   300/  469] train loss: 0.062 train accuracy: 1.000
# [37,   400/  469] train loss: 0.089 train accuracy: 0.984
# [38,   100/  469] train loss: 0.099 train accuracy: 0.977
# [38,   200/  469] train loss: 0.079 train accuracy: 0.992
# [38,   300/  469] train loss: 0.077 train accuracy: 0.984
# [38,   400/  469] train loss: 0.078 train accuracy: 1.000
# [39,   100/  469] train loss: 0.063 train accuracy: 1.000
# [39,   200/  469] train loss: 0.082 train accuracy: 1.000
# [39,   300/  469] train loss: 0.090 train accuracy: 0.984
# [39,   400/  469] train loss: 0.061 train accuracy: 1.000
# [40,   100/  469] train loss: 0.086 train accuracy: 0.984
# [40,   200/  469] train loss: 0.071 train accuracy: 1.000
# [40,   300/  469] train loss: 0.063 train accuracy: 1.000
# [40,   400/  469] train loss: 0.072 train accuracy: 1.000
# [41,   100/  469] train loss: 0.069 train accuracy: 1.000
# [41,   200/  469] train loss: 0.078 train accuracy: 0.992
# [41,   300/  469] train loss: 0.074 train accuracy: 1.000
# [41,   400/  469] train loss: 0.064 train accuracy: 1.000
# [42,   100/  469] train loss: 0.070 train accuracy: 1.000
# [42,   200/  469] train loss: 0.069 train accuracy: 1.000
# [42,   300/  469] train loss: 0.068 train accuracy: 0.992
# [42,   400/  469] train loss: 0.060 train accuracy: 0.992
# [43,   100/  469] train loss: 0.073 train accuracy: 0.992
# [43,   200/  469] train loss: 0.092 train accuracy: 0.977
# [43,   300/  469] train loss: 0.075 train accuracy: 0.984
# [43,   400/  469] train loss: 0.079 train accuracy: 0.984
# [44,   100/  469] train loss: 0.067 train accuracy: 1.000
# [44,   200/  469] train loss: 0.067 train accuracy: 0.992
# [44,   300/  469] train loss: 0.089 train accuracy: 0.977
# [44,   400/  469] train loss: 0.058 train accuracy: 1.000
# [45,   100/  469] train loss: 0.074 train accuracy: 1.000
# [45,   200/  469] train loss: 0.066 train accuracy: 1.000
# [45,   300/  469] train loss: 0.076 train accuracy: 1.000
# [45,   400/  469] train loss: 0.069 train accuracy: 1.000
# [46,   100/  469] train loss: 0.071 train accuracy: 1.000
# [46,   200/  469] train loss: 0.065 train accuracy: 1.000
# [46,   300/  469] train loss: 0.085 train accuracy: 0.992
# [46,   400/  469] train loss: 0.067 train accuracy: 1.000
# [47,   100/  469] train loss: 0.078 train accuracy: 1.000
# [47,   200/  469] train loss: 0.061 train accuracy: 1.000
# [47,   300/  469] train loss: 0.076 train accuracy: 1.000
# [47,   400/  469] train loss: 0.066 train accuracy: 1.000
# [48,   100/  469] train loss: 0.077 train accuracy: 1.000
# [48,   200/  469] train loss: 0.067 train accuracy: 1.000
# [48,   300/  469] train loss: 0.059 train accuracy: 1.000
# [48,   400/  469] train loss: 0.061 train accuracy: 1.000
# [49,   100/  469] train loss: 0.065 train accuracy: 1.000
# [49,   200/  469] train loss: 0.072 train accuracy: 0.992
# [49,   300/  469] train loss: 0.076 train accuracy: 1.000
# [49,   400/  469] train loss: 0.081 train accuracy: 0.992
# [50,   100/  469] train loss: 0.062 train accuracy: 1.000
# [50,   200/  469] train loss: 0.060 train accuracy: 1.000
# [50,   300/  469] train loss: 0.067 train accuracy: 0.992
# [50,   400/  469] train loss: 0.068 train accuracy: 0.992
# [51,   100/  469] train loss: 0.060 train accuracy: 1.000
# [51,   200/  469] train loss: 0.077 train accuracy: 0.977
# [51,   300/  469] train loss: 0.060 train accuracy: 1.000
# [51,   400/  469] train loss: 0.068 train accuracy: 1.000
# [52,   100/  469] train loss: 0.072 train accuracy: 1.000
# [52,   200/  469] train loss: 0.065 train accuracy: 0.992
# [52,   300/  469] train loss: 0.061 train accuracy: 1.000
# [52,   400/  469] train loss: 0.067 train accuracy: 1.000
# [53,   100/  469] train loss: 0.074 train accuracy: 0.992
# [53,   200/  469] train loss: 0.065 train accuracy: 1.000
# [53,   300/  469] train loss: 0.070 train accuracy: 1.000
# [53,   400/  469] train loss: 0.088 train accuracy: 0.992
# [54,   100/  469] train loss: 0.067 train accuracy: 1.000
# [54,   200/  469] train loss: 0.081 train accuracy: 0.992
# [54,   300/  469] train loss: 0.064 train accuracy: 1.000
# [54,   400/  469] train loss: 0.063 train accuracy: 1.000
# [55,   100/  469] train loss: 0.060 train accuracy: 1.000
# [55,   200/  469] train loss: 0.076 train accuracy: 0.992
# [55,   300/  469] train loss: 0.065 train accuracy: 0.992
# [55,   400/  469] train loss: 0.055 train accuracy: 0.992
# [56,   100/  469] train loss: 0.067 train accuracy: 1.000
# [56,   200/  469] train loss: 0.077 train accuracy: 0.992
# [56,   300/  469] train loss: 0.082 train accuracy: 0.992
# [56,   400/  469] train loss: 0.066 train accuracy: 0.984
# [57,   100/  469] train loss: 0.061 train accuracy: 1.000
# [57,   200/  469] train loss: 0.060 train accuracy: 1.000
# [57,   300/  469] train loss: 0.073 train accuracy: 0.992
# [57,   400/  469] train loss: 0.072 train accuracy: 0.992
# [58,   100/  469] train loss: 0.062 train accuracy: 1.000
# [58,   200/  469] train loss: 0.064 train accuracy: 0.992
# [58,   300/  469] train loss: 0.059 train accuracy: 0.992
# [58,   400/  469] train loss: 0.067 train accuracy: 0.992
# [59,   100/  469] train loss: 0.079 train accuracy: 0.992
# [59,   200/  469] train loss: 0.065 train accuracy: 1.000
# [59,   300/  469] train loss: 0.078 train accuracy: 0.984
# [59,   400/  469] train loss: 0.075 train accuracy: 0.992
# [60,   100/  469] train loss: 0.070 train accuracy: 0.992
# [60,   200/  469] train loss: 0.061 train accuracy: 0.992
# [60,   300/  469] train loss: 0.065 train accuracy: 0.992
# [60,   400/  469] train loss: 0.081 train accuracy: 0.992

# %%
# Calculate student test accuracy
_, test_accuracy = utils.getLossAccuracyOnDataset(student_net, test_loader, fast_device)
print('student test accuracy (w distillation): ', test_accuracy)
# Out:
# student test accuracy (w distillation):  0.9866
